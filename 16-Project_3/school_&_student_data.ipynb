# %%
import pandas as pd


df2019 = pd.read_csv("Resources/Cohort_2019.csv")
df2020 = pd.read_csv("Resources/Cohort_2020.csv")
df2021 = pd.read_csv("Resources/Cohort_2021.csv")
df2022 = pd.read_csv("Resources/Cohort_2022.csv")
df2023 = pd.read_csv("Resources/Cohort_2023.csv")

# %%
df2023
# Out:
#       Cohort Year Graduation Rate Type  LEA Entity ID  \
# 0            2023               4 Year           4153
# 1            2023               4 Year           4153
# 2            2023               4 Year           4153
# 3            2023               4 Year           4153
# 4            2023               4 Year           4153
# ...           ...                  ...            ...
# 6842         2023               4 Year        1001949
# 6843         2023               4 Year        1001949
# 6844         2023               4 Year        1001949
# 6845         2023               4 Year        1001949
# 6846         2023               4 Year        1001949
#
#                                  LEA Name  School Entity ID  \
# 0               St Johns Unified District              4711
# 1               St Johns Unified District              4711
# 2               St Johns Unified District              4711
# 3               St Johns Unified District              4711
# 4               St Johns Unified District              4711
# ...                                   ...               ...
# 6842  Arizona Goodwill Education Services           1001974
# 6843  Arizona Goodwill Education Services           1001974
# 6844  Arizona Goodwill Education Services           1001974
# 6845  Arizona Goodwill Education Services           1001974
# 6846  Arizona Goodwill Education Services           1001974
#
#                      School Name    County                          Subgroup  \
# 0           St Johns High School    Apache                               All
# 1           St Johns High School    Apache  American Indian or Alaska Native
# 2           St Johns High School    Apache                             Asian
# 3           St Johns High School    Apache            Black/African American
# 4           St Johns High School    Apache                  English Learners
# ...                          ...       ...                               ...
# 6842  The Excel Center - Encanto  Maricopa                            Female
# 6843  The Excel Center - Encanto  Maricopa                Hispanic or Latino
# 6844  The Excel Center - Encanto  Maricopa                              Male
# 6845  The Excel Center - Encanto  Maricopa                    Multiple Races
# 6846  The Excel Center - Encanto  Maricopa                             White
#
#      Number in Cohort Number Graduated Percent Graduated in 4 Years
# 0                  60                *                            *
# 1                   *                *                            *
# 2                   *                *                            *
# 3                   *                *                            *
# 4                   *                *                            *
# ...               ...              ...                          ...
# 6842              106                *                            *
# 6843               65                *                            *
# 6844               27                *                            *
# 6845                *                *                            *
# 6846               32                *                            *
#
# [6847 rows x 11 columns]
