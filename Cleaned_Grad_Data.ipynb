# %%
import pandas as pd

df = pd.read_csv("Tables/Yr2023_Grad_Data.csv")

# %%
df.head()
# Out:
#    School_ID                                School_Name  \
# 0     969999  Hope College and Career Readiness Academy
# 1     969999  Hope College and Career Readiness Academy
# 2     969999  Hope College and Career Readiness Academy
# 3     969999  Hope College and Career Readiness Academy
# 4     969999  Hope College and Career Readiness Academy
#
#                       Subgroup_Name No_in_Class No_Graduated Percent_Graduated
# 0                               All          30            *                 *
# 1  American Indian or Alaska Native           *            *                 *
# 2            Black/African American           *            *                 *
# 3                  English Learners           *            *                 *
# 4                           ELFEP14           *            *                 *

# %%
df.replace('*', 0, inplace=True)

df.head()
# Out:
#    School_ID                                School_Name  \
# 0     969999  Hope College and Career Readiness Academy
# 1     969999  Hope College and Career Readiness Academy
# 2     969999  Hope College and Career Readiness Academy
# 3     969999  Hope College and Career Readiness Academy
# 4     969999  Hope College and Career Readiness Academy
#
#                       Subgroup_Name No_in_Class No_Graduated Percent_Graduated
# 0                               All          30            0                 0
# 1  American Indian or Alaska Native           0            0                 0
# 2            Black/African American           0            0                 0
# 3                  English Learners           0            0                 0
# 4                           ELFEP14           0            0                 0

# %%
df.to_csv('Yr2023_Grad_Data_cleaned.csv', index=False)
